# %%
for i in range(5):
    print(i, end=" ")
# Out:
# 0 1 2 3 4

# %%
aList = [10, 20, 30, 40, 50, 60, 70, 80] 
print(aList[2:5]) 
print(aList[:4]) 
print(aList[3:])
# Out:
# [30, 40, 50]
# [10, 20, 30, 40]
# [40, 50, 60, 70, 80]

# %%
x = -5
if x >= 0:
    if x == 0:
        print("Zero")
    else:
        print("Positive")
else:
    print("Negative")
# Out:
# Negative

# %%
list1 = ['physics', 'chemistry', 1997, 2000]
print (list1[1][-1])
# Out:
# y

# %%
x = 3
while x > 0:
  x -= 1
  print(x)
# Out:
# 2
# 1
# 0

# %%
# for i in range(5):
#         print(i)
# else
# print("Done")?
# Out:
#   Cell In[7], line 3
#     else
#         ^
# SyntaxError: expected ':'

# %%
for i in range(5):
    if i==0:
        continue
    print(i)
# Out:
# 1
# 2
# 3
# 4

# %%
num=5
while num > 0:
    print(num)
    num -= 1
    if num == 3:
        break
else:
    print("Done")
# Out:
# 5
# 4
