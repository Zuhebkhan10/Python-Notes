# %%
l = ['apple','Apple','Banana','banana','grapes','pineapple']
#sort the list in alphabetical order
l.sort(reverse= True)
print(l)
# Out:
# ['pineapple', 'grapes', 'banana', 'apple', 'Banana', 'Apple']

# %% [markdown]
# #Note:- sorting can be done based om ASCII values
