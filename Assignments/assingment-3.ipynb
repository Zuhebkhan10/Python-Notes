# %%
a="Python"
print(a[2:])
# Out:
# thon

# %%
l=[10,20,30]
print(l.pop(1))
# Out:
# 20

# %%
l=[10,20,30]
print(l+[40,50])
# Out:
# [10, 20, 30, 40, 50]

# %%
l=[1,2,3]
print(l.count(2))
# Out:
# 1

# %%
i=0
whie i<5:
    print(i)
# Out:
#   Cell In[7], line 2
#     whie i<5:
#          ^
# SyntaxError: invalid syntax

# %%
for i in range(2,11,2):
    print(i)
# Out:
# 2
# 4
# 6
# 8
# 10

# %%
l=[1,2,3]
print(l.extend[20,30])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 2
#       1 l=[1,2,3]
# ----> 2 print(l.extend[20,30])
#
# TypeError: 'builtin_function_or_method' object is not subscriptable

# %%
for i in range(5):
    if i==3:
        continue
    print(i)
# Out:
# 0
# 1
# 2
# 4

# %%
s="Python"
# print(s[-3:])
print(s[::-1])
# Out:
# nohtyP

# %%
l=[2,3,4]
l*=2
print(l)
# Out:
# [2, 3, 4, 2, 3, 4]

# %%
l=[10,20,30]
l.append(44)
print(l)
# Out:
# [10, 20, 30, 44]

# %%
list=[[1,2],[3,4]]
print(list[0][1])
# Out:
# 2

# %%
def add(2,3):
    return a+b
print(add(2,3))
# Out:
#   Cell In[22], line 1
#     def add(2,3):
#             ^
# SyntaxError: invalid syntax

# %%
l=[1,2,3]
t=tuple(l)
print(t)
# Out:
# (1, 2, 3)

# %%
d="DataScience"
print(d[4:7])
# Out:
# Sci
