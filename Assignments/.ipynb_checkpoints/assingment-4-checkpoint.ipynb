# %%
# Write the program is calculator
print("Welcome to the calculator ")

a=float(input("Enter first number"))
b=float(input("Enter second number"))

print("1.add 2.sub 3.multiply 4.divide")
c=int(input("Chosse the option"))

if c==1:
    print("the result is ",a+b)
elif c==2:
    print("the result is ",a-b)
elif c==3:
    print("the result is",a*b)
elif c==4:
    print("the result is ",a/b)
else:
    print("Invalid option")

# %%
#leap years
year=int(input("Enter the year"))

if (year%4==0 and year%100!=0)or(year%400==0):
    print("Leap year")
else:
    print("Not a leap year")

# %%
# Text-Based Adventure Game
print("Welcome to the Adventure-Game")

a=input("you are at a crossroads.Go left or right ").lower()

if a=="left":
    print("Found the a treasure")
elif a=="right":
    print("You met a monester")
else:
    print("Invalid option")
# Out:
# Welcome to the Adventure-Game
# you are at a crossroads.Go left or right  right
# You met a monester

# %%
 # Number Guessing Game
import random 
number=random.randint(1,10)

a=int(input("Enter guess the number"))
if a==number:
    print("Congratualtions you guessed correctly")
else:
    print("Sorry the correct number was",number)

# %%
#  Password Generator
import random
import string

length = int(input("Enter password length: "))

char = string.ascii_letters + string.digits + string.punctuation
password = ""

for i in range(length):
    password += random.choice(char)
print("Generated Password:", password)
# Out:
# Enter password length:  8
# Generated Password: *-k1HxQ>

# %%
# Dice Rolling Simulator
import random
# roll=random.randint(1,6)
# print("Yoy rolled",roll)

roll=random.randint(1,6)
if a==roll:
    print("Congrates you rolled the dice",a)
else:
    print("Please try again")

# %%
# Mad Libs Generator
adj=input("Enter a adjective")

n=input("Enter a noun")
v=input("Enter a verb")

print("I am",adj,n,"likes to",v,"every day")

# %%
# Currency Converter Dollar to rupees
amount=float(input("Enter the amount any currency"))
INR=amount
# print("Amount is INR ",rupees)
print("1.Dollar 2.riyal 3.darham 4.dinar")
currency=int(input("Select the currency"))
if currency==1:
    print("Amount is INR currency",INR*91.10)
elif currency==2:
    print("Amount is INR currency",INR*23.22)
elif currency==3:
    print("Amount is INR currency",INR*24.47)
elif currency==4:
    print("Amount is INR currency",INR*294.10)
else:
    print("Wrong option choose then Error")

# %%
# Word Counter
s=input("Enter a senetnce")
words=s.split()

print("Number of words",len(words))

# %%
# Quiz Program
print("Quiz time")

ans=input("What is capital of hyedrabad")
if ans.lower()=="Telangana":
    print("Yes its correct")
else:
    print("No its Incorrect")
