# %%
#Check the tenrary operator min and max values/
a,b=10,20
min= a if a<b else b
max= a if a>b else b
print(min)
print(max)
# Out:
# 10
# 20

# %%
name="Zoya"
# name="khan"
age=10
if name=="Zoya" or name =="Khan" and age>=2:
    print("Hello duniya")
else :
    print("good bye")

check =10+10*20
print(check)
# Out:
# Hello duniya
# 210

# %%
# Operator Associativity

print(100 / 10 * 10) 
print(5 - 2 + 3)
print(5 - (2 + 3))
print(2 ** 3 ** 2)
print(50/2 +100)
# Out:
# 100.0
# 6
# 0
# 512
# 125.0
