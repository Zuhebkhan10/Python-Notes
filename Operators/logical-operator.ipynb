# %%
a = True
b = False
print(a and b)
print(a or b)
print(not a)
# Out:
# False
# True
# False

# %%
# Logical AND
a=50
b=15
c=20
if b<a and c>b and  a>c:
    print("Logical code is execution")
else:
    print("Not execution the code")
# Out:
# Logical code is execution

# %%
# Logical OR
a=50
b=40
c=90
d=110
if (a<b or c>b):
    print("All condition are true")
else :
    print("Not satisfied")
# Out:
# All condition are true

# %%
#Logical Not
a=100
b=120
if(a==b):
    print("Condition are true ")
else :
    print("Not satisfied")
# Out:
# Not satisfied
