# %%
# For loop: It runs set of Instruction over each and evry element int he collection or iretabl 


l=[1,2,3,45,6,7,8,6,8,9]
for i in l:
    print(i*2,end=" ")
    # i is known as intializer or iterator
# Out:
# 2 4 6 90 12 14 16 12 16 18

# %%
# print the even numbers from above dataset.
i=[2,3,44,50,77,90,32,12]
for j in i:
    if(j%2==0):
        print(j)
# Out:
# 2
# 44
# 50
# 90
# 32
# 12

# %%
#From above list print the numbe those are divisible with 3.
a=[23,4,15,3,44,55,12,31,30]
for i in a:
    if(i%3==0):
        print(i)
# Out:
# 15
# 3
# 12
# 30
