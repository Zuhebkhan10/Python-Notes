# %%
# What is the loop
Loop 
# How many types of loops
# For loop
# While loop

# For loop: 
# While loop:

# %%
# Write a program to instruct 
target=5
initial=1
while initial<=target:
    print("GO up")
    print("Go down")
    print("_________Rep complete________",initial)
    initial=initial+1
# Out:
# GO up
# Go down
# _________Rep complete________ 1
# GO up
# Go down
# _________Rep complete________ 2
# GO up
# Go down
# _________Rep complete________ 3
# GO up
# Go down
# _________Rep complete________ 4
# GO up
# Go down
# _________Rep complete________ 5
